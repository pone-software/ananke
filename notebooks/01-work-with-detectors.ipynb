# %% [markdown]
# # 01 Work with Detectors
#
# This notebook is all about how to get a detector to work with in simulation or data analysis. A detector can be generated by using a configuration. This configuration is loadable and saveable using the library [Pydantic](https://pydantic-docs.helpmanual.io/) which ensures solid typing, validation and serialization from and to json.
#
# ## Table of Contents
#
# 1. [Import Dependencies](#dependencies)
# 2. [Playing around with the configuration](#configuration)
# 3. [Creating a detector](#detector)
# 4. [Visualizing a detector](#visualization)
#
# ## Import dependencies <a class="anchor" id="dependencies"></a>

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../')

import numpy as np

# %% [markdown]
# ## Playing around with the Configuration <a class="anchor" id="configuration"></a>
#
# The configuration is written in a way that its easy to persist and pass around. Like that a detector can be recreated easily using the configuration. Later on when generating multiple datasets, having this interoperability will be crucial in making knowledge transferable.
#
# Each configuration contains four parts:
# * **geometry:** Contains the details on the detector's geometry (e.g. triangular)
# * **string:** Contains the details on the properties for each string
# * **module:** Contains the details on the properties for each module
# * **pmt:** Contains the details on the properties for each pmt
#
# In addition, the property `seed` can be set to ensure all random processes within the detector generation, like setting PMT noise rates can be fixed. Let's look at some examples:

# %%
from ananke.schemas.detector import StringConfiguration, PMTConfiguration, ModuleConfiguration, \
    LengthGeometryConfiguration, DetectorConfiguration, DetectorGeometries

string_configuration = StringConfiguration(
    z_offset=50.0,
    module_number=20,
    module_distance=50.0
)

pmt_configuration = PMTConfiguration(
    efficiency= 0.4,
    noise_rate = 1e-6,
    gamma_scale = .25
)

module_configuration = ModuleConfiguration(
    radius=20
)

geometry_configuration = LengthGeometryConfiguration(
    type=DetectorGeometries.TRIANGULAR,
    side_length=100
)

detector_configuration = DetectorConfiguration(
    geometry=geometry_configuration,
    string=string_configuration,
    module=module_configuration,
    pmt=pmt_configuration,
    seed=1337
)

print(detector_configuration)
# Out:
# geometry=LengthGeometryConfiguration(start_position=Position(x=0.0, y=0.0), type=<DetectorGeometries.TRIANGULAR: 'triangular'>, side_length=100) string=StringConfiguration(z_offset=50.0, module_number=20, module_distance=50.0) module=ModuleConfiguration(radius=20.0, include_pmts=True) pmt=PMTConfiguration(efficiency=0.4, noise_rate=1e-06, gamma_scale=0.25) seed=1337

# %% [markdown]
# Tha looks fantastic, does not it. Only problem is that you have to create quite a lot of classes. Meet the power of pydantic. We can just create a dict which could be read via json or yaml and go from there. Is not that fantastic? As I am lazy, you can as well check out some default values

# %%
configuration = {
    "string": {
        "module_number": 20,
        "module_distance": 50
    },
    "pmt": {
        "efficiency": 0.4
    },
    "module": {
        "radius": 15
    },
    "geometry": {
        "type": "triangular",
        "side_length": 100,
    },
    "seed": 4545
}

detector_configuration_dict = DetectorConfiguration.parse_obj(configuration)

print(detector_configuration_dict)
# Out:
# geometry=LengthGeometryConfiguration(start_position=Position(x=0.0, y=0.0), type=<DetectorGeometries.TRIANGULAR: 'triangular'>, side_length=100) string=StringConfiguration(z_offset=0.0, module_number=20, module_distance=50.0) module=ModuleConfiguration(radius=15.0, include_pmts=True) pmt=PMTConfiguration(efficiency=0.4, noise_rate=0.00016, gamma_scale=0.0) seed=4545

# %% [markdown]
# And it gets even better. This is totally error proof (as long as the code is correct in typing). Let's check it out!

# %%
configuration = {
    "string": {
        "module_number": 20
    },
    "pmt": {
        "efficiency": 0.4
    },
    "module": {
        "radius": 15
    },
    "geometry": {
        "type": "triangular",
        "side_length": 100,
    },
    "seed": 4545
}

detector_configuration_err = DetectorConfiguration.parse_obj(configuration)

print(detector_configuration_err)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In [4], line 18
#       1 configuration = {
#       2     "string": {
#       3         "module_number": 20
#    (...)
#      15     "seed": 4545
#      16 }
# ---> 18 detector_configuration_err = DetectorConfiguration.parse_obj(configuration)
#      20 print(detector_configuration_err)
#
# File ~/.cache/pypoetry/virtualenvs/pone-ananke-dM-E5NyI-py3.8/lib/python3.8/site-packages/pydantic/main.py:526, in pydantic.main.BaseModel.parse_obj()
#
# File ~/.cache/pypoetry/virtualenvs/pone-ananke-dM-E5NyI-py3.8/lib/python3.8/site-packages/pydantic/main.py:342, in pydantic.main.BaseModel.__init__()
#
# ValidationError: 1 validation error for DetectorConfiguration
# string -> module_distance
#   field required (type=value_error.missing)

# %%
configuration = {
    "string": {
        "module_number": "peter"
    },
    "pmt": {
        "efficiency": 5
    },
    "module": {
        "radius": -1
    },
    "geometry": {
        "type": "triangular",
        "number_of_strings_per_side": 45
    },
    "seed": 4545
}

detector_configuration_err = DetectorConfiguration.parse_obj(configuration)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In [5], line 18
#       1 configuration = {
#       2     "string": {
#       3         "module_number": "peter"
#    (...)
#      15     "seed": 4545
#      16 }
# ---> 18 detector_configuration_err = DetectorConfiguration.parse_obj(configuration)
#
# File ~/.cache/pypoetry/virtualenvs/pone-ananke-dM-E5NyI-py3.8/lib/python3.8/site-packages/pydantic/main.py:526, in pydantic.main.BaseModel.parse_obj()
#
# File ~/.cache/pypoetry/virtualenvs/pone-ananke-dM-E5NyI-py3.8/lib/python3.8/site-packages/pydantic/main.py:342, in pydantic.main.BaseModel.__init__()
#
# ValidationError: 5 validation errors for DetectorConfiguration
# geometry -> LengthGeometryConfiguration -> side_length
#   field required (type=value_error.missing)
# string -> module_number
#   value is not a valid integer (type=type_error.integer)
# string -> module_distance
#   field required (type=value_error.missing)
# module -> radius
#   ensure this value is greater than 0 (type=value_error.number.not_gt; limit_value=0)
# pmt -> efficiency
#   ensure this value is less than or equal to 1 (type=value_error.number.not_le; limit_value=1)

# %% [markdown]
# Covering all possible errors here is impossible, but the idea should be clear right now.

# %% [markdown]
# ## Creating a detector <a class="anchor" href="detector"></a>
#
# Now we know how to handle the configurations. Let's create a detector. Wait for the magic:

# %%
from ananke.services.detector import DetectorBuilderService

configuration = {
    "string": {
        "module_number": 1,
        "module_distance": 50
    },
    "pmt": {
        "efficiency": 0.4
    },
    "module": {
        "radius": 15
    },
    "geometry": {
        "type": "triangular",
        "side_length": 100,
    },
    "seed": 4545
}

detector_configuration = DetectorConfiguration.parse_obj(configuration)

detector_service = DetectorBuilderService()

detector = detector_service.get(detector_configuration)

#print(detector)
# Out:
# (16, 9)
# (16, 9)
# (16, 9)

# %% [markdown]
# That is how easy it gets :) As a numpy array, we get an array containing all the modules/pmts positions with the ids for string, module and:

# %%
print(np.array(detector))
# Out:
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 -5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01  0.00000000e+00
#    2.44346095e+00]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00 -5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01 -0.00000000e+00
#    6.98131701e-01]
#  [ 0.00000000e+00  0.00000000e+00  2.00000000e+00 -5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01 -9.87800528e-01
#    2.26640965e+00]
#  [ 0.00000000e+00  0.00000000e+00  3.00000000e+00 -5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01  9.87800528e-01
#    8.75183006e-01]
#  [ 0.00000000e+00  0.00000000e+00  4.00000000e+00 -5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01  8.72664626e-01
#    1.57079633e+00]
#  [ 0.00000000e+00  0.00000000e+00  5.00000000e+00 -5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01 -8.72664626e-01
#    1.57079633e+00]
#  [ 0.00000000e+00  0.00000000e+00  6.00000000e+00 -5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01 -9.87800528e-01
#    8.75183006e-01]
#  [ 0.00000000e+00  0.00000000e+00  7.00000000e+00 -5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01  9.87800528e-01
#    2.26640965e+00]
#  [ 0.00000000e+00  0.00000000e+00  8.00000000e+00 -5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01  1.45947722e-16
#    6.98131701e-01]
#  [ 0.00000000e+00  0.00000000e+00  9.00000000e+00 -5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01 -1.45947722e-16
#    2.44346095e+00]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+01 -5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01  9.87800528e-01
#    8.75183006e-01]
#  [ 0.00000000e+00  0.00000000e+00  1.10000000e+01 -5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01 -9.87800528e-01
#    2.26640965e+00]
#  [ 0.00000000e+00  0.00000000e+00  1.20000000e+01 -5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01 -8.72664626e-01
#    1.57079633e+00]
#  [ 0.00000000e+00  0.00000000e+00  1.30000000e+01 -5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01  8.72664626e-01
#    1.57079633e+00]
#  [ 0.00000000e+00  0.00000000e+00  1.40000000e+01 -5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01  9.87800528e-01
#    2.26640965e+00]
#  [ 0.00000000e+00  0.00000000e+00  1.50000000e+01 -5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01 -9.87800528e-01
#    8.75183006e-01]
#  [ 1.00000000e+00  0.00000000e+00  0.00000000e+00  5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01  0.00000000e+00
#    2.44346095e+00]
#  [ 1.00000000e+00  0.00000000e+00  1.00000000e+00  5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01 -0.00000000e+00
#    6.98131701e-01]
#  [ 1.00000000e+00  0.00000000e+00  2.00000000e+00  5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01 -9.87800528e-01
#    2.26640965e+00]
#  [ 1.00000000e+00  0.00000000e+00  3.00000000e+00  5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01  9.87800528e-01
#    8.75183006e-01]
#  [ 1.00000000e+00  0.00000000e+00  4.00000000e+00  5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01  8.72664626e-01
#    1.57079633e+00]
#  [ 1.00000000e+00  0.00000000e+00  5.00000000e+00  5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01 -8.72664626e-01
#    1.57079633e+00]
#  [ 1.00000000e+00  0.00000000e+00  6.00000000e+00  5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01 -9.87800528e-01
#    8.75183006e-01]
#  [ 1.00000000e+00  0.00000000e+00  7.00000000e+00  5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01  9.87800528e-01
#    2.26640965e+00]
#  [ 1.00000000e+00  0.00000000e+00  8.00000000e+00  5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01  1.45947722e-16
#    6.98131701e-01]
#  [ 1.00000000e+00  0.00000000e+00  9.00000000e+00  5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01 -1.45947722e-16
#    2.44346095e+00]
#  [ 1.00000000e+00  0.00000000e+00  1.00000000e+01  5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01  9.87800528e-01
#    8.75183006e-01]
#  [ 1.00000000e+00  0.00000000e+00  1.10000000e+01  5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01 -9.87800528e-01
#    2.26640965e+00]
#  [ 1.00000000e+00  0.00000000e+00  1.20000000e+01  5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01 -8.72664626e-01
#    1.57079633e+00]
#  [ 1.00000000e+00  0.00000000e+00  1.30000000e+01  5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01  8.72664626e-01
#    1.57079633e+00]
#  [ 1.00000000e+00  0.00000000e+00  1.40000000e+01  5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01  9.87800528e-01
#    2.26640965e+00]
#  [ 1.00000000e+00  0.00000000e+00  1.50000000e+01  5.00000000e+01
#   -2.88675135e+01  0.00000000e+00  1.50000000e+01 -9.87800528e-01
#    8.75183006e-01]
#  [ 2.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    5.77350269e+01  0.00000000e+00  1.50000000e+01  0.00000000e+00
#    2.44346095e+00]
#  [ 2.00000000e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#    5.77350269e+01  0.00000000e+00  1.50000000e+01 -0.00000000e+00
#    6.98131701e-01]
#  [ 2.00000000e+00  0.00000000e+00  2.00000000e+00  0.00000000e+00
#    5.77350269e+01  0.00000000e+00  1.50000000e+01 -9.87800528e-01
#    2.26640965e+00]
#  [ 2.00000000e+00  0.00000000e+00  3.00000000e+00  0.00000000e+00
#    5.77350269e+01  0.00000000e+00  1.50000000e+01  9.87800528e-01
#    8.75183006e-01]
#  [ 2.00000000e+00  0.00000000e+00  4.00000000e+00  0.00000000e+00
#    5.77350269e+01  0.00000000e+00  1.50000000e+01  8.72664626e-01
#    1.57079633e+00]
#  [ 2.00000000e+00  0.00000000e+00  5.00000000e+00  0.00000000e+00
#    5.77350269e+01  0.00000000e+00  1.50000000e+01 -8.72664626e-01
#    1.57079633e+00]
#  [ 2.00000000e+00  0.00000000e+00  6.00000000e+00  0.00000000e+00
#    5.77350269e+01  0.00000000e+00  1.50000000e+01 -9.87800528e-01
#    8.75183006e-01]
#  [ 2.00000000e+00  0.00000000e+00  7.00000000e+00  0.00000000e+00
#    5.77350269e+01  0.00000000e+00  1.50000000e+01  9.87800528e-01
#    2.26640965e+00]
#  [ 2.00000000e+00  0.00000000e+00  8.00000000e+00  0.00000000e+00
#    5.77350269e+01  0.00000000e+00  1.50000000e+01  1.45947722e-16
#    6.98131701e-01]
#  [ 2.00000000e+00  0.00000000e+00  9.00000000e+00  0.00000000e+00
#    5.77350269e+01  0.00000000e+00  1.50000000e+01 -1.45947722e-16
#    2.44346095e+00]
#  [ 2.00000000e+00  0.00000000e+00  1.00000000e+01  0.00000000e+00
#    5.77350269e+01  0.00000000e+00  1.50000000e+01  9.87800528e-01
#    8.75183006e-01]
#  [ 2.00000000e+00  0.00000000e+00  1.10000000e+01  0.00000000e+00
#    5.77350269e+01  0.00000000e+00  1.50000000e+01 -9.87800528e-01
#    2.26640965e+00]
#  [ 2.00000000e+00  0.00000000e+00  1.20000000e+01  0.00000000e+00
#    5.77350269e+01  0.00000000e+00  1.50000000e+01 -8.72664626e-01
#    1.57079633e+00]
#  [ 2.00000000e+00  0.00000000e+00  1.30000000e+01  0.00000000e+00
#    5.77350269e+01  0.00000000e+00  1.50000000e+01  8.72664626e-01
#    1.57079633e+00]
#  [ 2.00000000e+00  0.00000000e+00  1.40000000e+01  0.00000000e+00
#    5.77350269e+01  0.00000000e+00  1.50000000e+01  9.87800528e-01
#    2.26640965e+00]
#  [ 2.00000000e+00  0.00000000e+00  1.50000000e+01  0.00000000e+00
#    5.77350269e+01  0.00000000e+00  1.50000000e+01 -9.87800528e-01
#    8.75183006e-01]]
